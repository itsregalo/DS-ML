# %%
import matplotlib.pyplot as plt

# %%
#used to display the plots in the notebook
# %matplotlib inline

# %%
import numpy as np
dataX = np.linspace(0,5,11)
dataY = dataX ** 2

# %%
dataX
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
dataY
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(dataX, dataY,)
plt.xlabel('X')
plt.ylabel('X2')
plt.title('XY')
# Out:
# Text(0.5, 1.0, 'XY')

# %%
plt.subplot(1,2,1)
plt.plot(dataX,dataY,'b')

plt.subplot(1,2,2)
plt.plot(dataY,dataX,'r')

# %%
#object oriented

figure1 = plt.figure()
axes = figure1.add_axes([0.1,0.1,0.8,0.8])
axes.plot(dataX,dataY,'r')
axes.set_xlabel('X')
axes.set_ylabel('Y')
axes.set_title('X and Y axis')
# Out:
# Text(0.5, 1.0, 'X and Y axis')

# %%
figure2 = plt.figure()
axes1 = figure2.add_axes([0.1,0.1,0.8,0.8])
axes2 = figure2.add_axes([0.15,0.35,0.35,0.4])

axes1.plot(dataX,dataY)
axes1.set_title("LARGER")
axes2.plot(dataY,dataX)
axes2.set_title("SMALLER")
# Out:
# Text(0.5, 1.0, 'SMALLER')

# %% [markdown]
# ### Subplots

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
plt.tight_layout()

axes[0].plot(dataX,dataY)
axes[0].set_title("AXES 1")


axes[1].plot(dataY,dataX)
axes[1].set_title("AXES 2")
# Out:
# Text(0.5, 1.0, 'AXES 2')

# %% [markdown]
# ### Figure size and DPI

# %%
#format: plt.figure(nrows, ncols, figsize(l,w), dpi=<dpi>)
fig1, axes = plt.subplots(nrows=1, ncols=2, figsize=(8,5))

axes[0].plot(dataX, dataY)
axes[1].plot(dataY, dataX)

# %% [markdown]
# ### Saving a figure

# %%
#use save figure method
fig1.savefig('pic1.png', dpi=500)
fig.savefig('pic2.png', dpi=500)

# %%
 figure2.savefig('subplot.png')

# %% [markdown]
# ### Legends

# %%
figLagend = plt.figure()

ax = figLagend.add_axes([0,0,1,1])
ax.plot(dataX, dataY, label="X squared")
ax.plot(dataX, dataX**3, label = "X cubed")

#legends
ax.legend(loc=0)

# %% [markdown]
# ### location codes
# * Location String	Location Code
# * best'%   	    0
# * upper right'	1
# * 'upper left'	2
# * 'lower left'	3
# * 'lower right'	4
# * 'right'     	 5
# * 'center left'	6
# * 'center right'	7
# * 'lower center'	8
# * 'upper center'	9
# * 'center'	10

# %% [markdown]
# ### Plot Appearance

# %%
# https://matplotlib.org/stable/api/markers_api.html 
figAppearance = plt.figure()

ax = figAppearance.add_axes([0,0,1,1])
#color codes can also work
ax.plot(dataX, dataY, color='red', 
        linewidth=2,
        alpha=2,
        marker='s',
        markerfacecolor='green',
        markeredgecolor='green',
       )

#other arguments:
#inestyle='--'

# %% [markdown]
# ### Axis appearance

# %%
figAxis= plt.figure()

ax = figAxis.add_axes([0,0,1,1])
#color codes can also work
ax.plot(dataX, dataY, color='red', 
        linewidth=2,
        alpha=2,
        marker='s',
        markerfacecolor='green',
        markeredgecolor='green',
       )

#setting limits

#ax.set_xlim([min,max])
#ax.set_ylim([min,max])

ax.set_xlim([0,1])
ax.set_ylim([0,1])
# Out:
# (0.0, 1.0)

# %%
plt.scatter(dataX, dataY)
