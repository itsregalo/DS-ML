# %%
import pandas as pd; 
#read the data from the xlsx file
data = pd.read_excel('Copy_of_UNC_Weight_Management_Feedback_March.25.2022_00.50.xlsx')

# %%
# get data head
data.head()
# Out:
#              StartDate              EndDate  Progress  Duration (in seconds)  \
# 0           Start Date             End Date  Progress  Duration (in seconds)
# 1  2022-02-18 21:22:22  2022-02-18 21:26:04       100                    221
# 2  2022-02-19 10:18:03  2022-02-19 10:20:08       100                    125
# 3  2022-02-28 12:13:25  2022-02-28 12:16:34       100                    188
# 4  2022-03-01 11:03:37  2022-03-01 11:09:16       100                    338
#
#    Finished                RecordedDate   DistributionChannel   UserLanguage  \
# 0  Finished               Recorded Date  Distribution Channel  User Language
# 1      True  2022-02-18 21:26:04.587000             anonymous             EN
# 2      True  2022-02-19 10:20:08.833000             anonymous             EN
# 3      True  2022-02-28 12:16:34.490000             anonymous             EN
# 4      True  2022-03-01 11:09:16.791000             anonymous             EN
#
#                        Q1                   Q2  ...  \
# 0  Age group? (Check one)  Gender? (Check one)  ...
# 1                   66-86                 Male  ...
# 2                   36-65               Female  ...
# 3                   36-65               Female  ...
# 4                   36-65                 Male  ...
#
#                                                   Q8  \
# 0  If you DID complete at least 12 weeks of the p...
# 1                                                 12
# 2                                                NaN
# 3                                             Unsure
# 4                                                 12
#
#                                                   Q9  \
# 0  Were you using any other tools or services for...
# 1                                                 No
# 2                         Unsure / Prefer not to say
# 3                                                 No
# 4                                                Yes
#
#                                                  Q10  \
# 0  If you have tried other weight management inte...
# 1                                                NaN
# 2          Same as the info I was given in my appt.
# 3  Emory University Barriatric program - liquid d...
# 4                             Gastric Sleeve Surgery
#
#                                                  Q11  \
# 0  What, if any,  other benefits did you experien...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Understanding about Set Point, a new concept f...
#
#                                                  Q12  \
# 0  Was information and instruction given during t...
# 1                                                Yes
# 2                                                Yes
# 3                                                 No
# 4                                                Yes
#
#                                                  Q13  \
# 0  Was your overall experience in the program pos...
# 1                                           Positive
# 2                         Unsure / Prefer not to say
# 3                         Unsure / Prefer not to say
# 4                                           Positive
#
#                                                  Q14  \
# 0  What is the primary reason for your response t...
# 1                                Helped me to focus
# 2                                                NaN
# 3                   Your questions aren't numbered.
# 4                    Clear explanation by the nurse.
#
#                                                  Q15  \
# 0  Would you recommend this program to someone in...
# 1                                    Yes, Definitely
# 2                                      Yes, Probably
# 3                                                 No
# 4                                    Yes, Definitely
#
#                                                  Q16  \
# 0  What is the primary reason for your response t...
# 1                               Positive experience
# 2                                                NaN
# 3                  Program seems very unstructured.
# 4  It helped me understand the root cause of my w...
#
#                                                  Q17
# 0  Do you have any suggestions or comments that y...
# 1                                                NaN
# 2                                                NaN
# 3              More structure. Better meal planning.
# 4                                                NaN
#
# [5 rows x 25 columns]

# %%
# remove the second row because its repeating the headers
data1 = data.drop(data.index[0])
#diplay the data header without the second row
data1.head()
# Out:
#              StartDate              EndDate Progress Duration (in seconds)  \
# 1  2022-02-18 21:22:22  2022-02-18 21:26:04      100                   221
# 2  2022-02-19 10:18:03  2022-02-19 10:20:08      100                   125
# 3  2022-02-28 12:13:25  2022-02-28 12:16:34      100                   188
# 4  2022-03-01 11:03:37  2022-03-01 11:09:16      100                   338
# 5  2022-03-01 12:23:05  2022-03-01 12:25:04      100                   118
#
#   Finished                RecordedDate DistributionChannel UserLanguage  \
# 1     True  2022-02-18 21:26:04.587000           anonymous           EN
# 2     True  2022-02-19 10:20:08.833000           anonymous           EN
# 3     True  2022-02-28 12:16:34.490000           anonymous           EN
# 4     True  2022-03-01 11:09:16.791000           anonymous           EN
# 5     True  2022-03-01 12:25:04.940000           anonymous           EN
#
#       Q1      Q2  ...      Q8                          Q9  \
# 1  66-86    Male  ...      12                          No
# 2  36-65  Female  ...     NaN  Unsure / Prefer not to say
# 3  36-65  Female  ...  Unsure                          No
# 4  36-65    Male  ...      12                         Yes
# 5  66-86    Male  ...      11                          No
#
#                                                  Q10  \
# 1                                                NaN
# 2          Same as the info I was given in my appt.
# 3  Emory University Barriatric program - liquid d...
# 4                             Gastric Sleeve Surgery
# 5                                                NaN
#
#                                                  Q11  Q12  \
# 1                                                NaN  Yes
# 2                                                NaN  Yes
# 3                                                NaN   No
# 4  Understanding about Set Point, a new concept f...  Yes
# 5  I cam e to realize things about myself that I ...  Yes
#
#                           Q13                               Q14  \
# 1                    Positive               Helped me to focus
# 2  Unsure / Prefer not to say                               NaN
# 3  Unsure / Prefer not to say  Your questions aren't numbered.
# 4                    Positive   Clear explanation by the nurse.
# 5                    Positive                 because it helped
#
#                Q15                                                Q16  \
# 1  Yes, Definitely                               Positive experience
# 2    Yes, Probably                                                NaN
# 3               No                  Program seems very unstructured.
# 4  Yes, Definitely  It helped me understand the root cause of my w...
# 5  Yes, Definitely                              already did recommend
#
#                                      Q17
# 1                                    NaN
# 2                                    NaN
# 3  More structure. Better meal planning.
# 4                                    NaN
# 5                                    NaN
#
# [5 rows x 25 columns]

# %%
# remove rows with blank Duration (in seconds)
data2 = data1.dropna(subset=['Duration (in seconds)'])

# %%
# import stats which will use to compute the t-test
import scipy.stats as stats

# get the duration column head
duration_column = data2['Duration (in seconds)']
duration_column.head()
# Out:
# 1    221
# 2    125
# 3    188
# 4    338
# 5    118
# Name: Duration (in seconds), dtype: object

# %%
# calculate ttest using stats.ttest_1samp of duration_column since its a one sample t-test
t_test_duration = stats.ttest_1samp(duration_column, duration_column.mean())

# %%
# print the result with 4 decimal
print('t-test for duration: ', round(t_test_duration.statistic, 4), ' and p-value: ', round(t_test_duration.pvalue, 4))
# Out:
# t-test for duration:  0.0  and p-value:  1.0

# %%
data
# Out:
#               StartDate              EndDate  Progress  Duration (in seconds)  \
# 0            Start Date             End Date  Progress  Duration (in seconds)
# 1   2022-02-18 21:22:22  2022-02-18 21:26:04       100                    221
# 2   2022-02-19 10:18:03  2022-02-19 10:20:08       100                    125
# 3   2022-02-28 12:13:25  2022-02-28 12:16:34       100                    188
# 4   2022-03-01 11:03:37  2022-03-01 11:09:16       100                    338
# 5   2022-03-01 12:23:05  2022-03-01 12:25:04       100                    118
# 6   2022-03-03 10:53:47  2022-03-03 13:26:04       100                   9136
# 7   2022-02-25 09:01:22  2022-02-25 09:01:26         6                      4
# 8   2022-02-25 12:23:45  2022-02-25 12:23:54         6                      8
# 9   2022-02-26 18:03:08  2022-02-26 18:03:13         6                      4
# 10  2022-02-27 09:35:54  2022-02-27 09:37:49         6                    115
# 11  2022-03-09 09:11:15  2022-03-09 09:13:51       100                    155
# 12  2022-03-03 14:48:24  2022-03-03 14:51:44         6                    200
# 13  2022-03-18 12:55:08  2022-03-18 13:10:59       100                    950
# 14  2022-03-18 14:21:36  2022-03-18 14:31:40       100                    604
# 15  2022-03-18 19:50:39  2022-03-18 20:00:14       100                    575
# 16  2022-03-20 16:56:26  2022-03-20 17:07:05       100                    639
# 17  2022-03-20 20:44:57  2022-03-20 20:54:13       100                    555
# 18  2022-03-21 09:52:30  2022-03-21 09:58:26       100                    355
# 19  2022-03-22 01:25:25  2022-03-22 01:32:06       100                    400
# 20  2022-03-22 08:35:53  2022-03-22 08:41:24       100                    330
# 21  2022-03-23 11:12:06  2022-03-23 11:16:06       100                    240
# 22  2022-03-17 07:28:48  2022-03-17 07:29:18         6                     30
#
#     Finished                RecordedDate   DistributionChannel   UserLanguage  \
# 0   Finished               Recorded Date  Distribution Channel  User Language
# 1       True  2022-02-18 21:26:04.587000             anonymous             EN
# 2       True  2022-02-19 10:20:08.833000             anonymous             EN
# 3       True  2022-02-28 12:16:34.490000             anonymous             EN
# 4       True  2022-03-01 11:09:16.791000             anonymous             EN
# 5       True  2022-03-01 12:25:04.940000             anonymous             EN
# 6       True  2022-03-03 13:26:04.952000             anonymous             EN
# 7      False  2022-03-04 09:01:30.244000             anonymous             EN
# 8      False  2022-03-04 12:24:00.036000             anonymous             EN
# 9      False  2022-03-05 18:03:15.741000             anonymous             EN
# 10     False  2022-03-06 09:37:53.264000             anonymous             EN
# 11      True  2022-03-09 09:13:51.810000             anonymous             EN
# 12     False  2022-03-10 14:51:46.469000             anonymous             EN
# 13      True  2022-03-18 13:10:59.552000             anonymous             EN
# 14      True  2022-03-18 14:31:41.408000             anonymous             EN
# 15      True  2022-03-18 20:00:14.405000             anonymous             EN
# 16      True  2022-03-20 17:07:06.391000             anonymous             EN
# 17      True  2022-03-20 20:54:13.394000             anonymous             EN
# 18      True  2022-03-21 09:58:26.724000             anonymous             EN
# 19      True  2022-03-22 01:32:07.013000             anonymous             EN
# 20      True  2022-03-22 08:41:24.740000             anonymous             EN
# 21      True  2022-03-23 11:16:07.200000             anonymous             EN
# 22     False  2022-03-24 07:29:20.094000             anonymous             EN
#
#                         Q1                   Q2  ...  \
# 0   Age group? (Check one)  Gender? (Check one)  ...
# 1                    66-86                 Male  ...
# 2                    36-65               Female  ...
# 3                    36-65               Female  ...
# 4                    36-65                 Male  ...
# 5                    66-86                 Male  ...
# 6                    36-65               Female  ...
# 7                      NaN                  NaN  ...
# 8                      NaN                  NaN  ...
# 9                      NaN                  NaN  ...
# 10                     NaN                  NaN  ...
# 11                   36-65               Female  ...
# 12                     NaN                  NaN  ...
# 13                   25-35               Female  ...
# 14                   66-86               Female  ...
# 15                   66-86               Female  ...
# 16                   25-35               Female  ...
# 17                   66-86               Female  ...
# 18                   66-86               Female  ...
# 19                   36-65               Female  ...
# 20                   36-65               Female  ...
# 21                   66-86               Female  ...
# 22                     NaN                  NaN  ...
#
#                                                    Q8  \
# 0   If you DID complete at least 12 weeks of the p...
# 1                                                  12
# 2                                                 NaN
# 3                                              Unsure
# 4                                                  12
# 5                                                  11
# 6                                                  15
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                 12
# 14                                                NaN
# 15                                                 14
# 16                                                 12
# 17                                                 12
# 18                                                NaN
# 19                                                12+
# 20                                                 46
# 21                                                NaN
# 22                                                NaN
#
#                                                    Q9  \
# 0   Were you using any other tools or services for...
# 1                                                  No
# 2                          Unsure / Prefer not to say
# 3                                                  No
# 4                                                 Yes
# 5                                                  No
# 6                                                  No
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                 No
# 12                                                NaN
# 13                                                 No
# 14                                                Yes
# 15                                                 No
# 16                                                 No
# 17                                                 No
# 18                                                Yes
# 19                                                Yes
# 20                                                 No
# 21                                                 No
# 22                                                NaN
#
#                                                   Q10  \
# 0   If you have tried other weight management inte...
# 1                                                 NaN
# 2           Same as the info I was given in my appt.
# 3   Emory University Barriatric program - liquid d...
# 4                              Gastric Sleeve Surgery
# 5                                                 NaN
# 6                                     Weight Watchers
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13         South beach diet, before weigh management
# 14                                   Weight watchers
# 15                           Weight watchers, Optavia
# 16                           Keto, Fasting, slimfast
# 17                                               Keto
# 18                                               None
# 19                                               None
# 20                            weight watchers online
# 21                                                 WW
# 22                                                NaN
#
#                                                   Q11  \
# 0   What, if any,  other benefits did you experien...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   Understanding about Set Point, a new concept f...
# 5   I cam e to realize things about myself that I ...
# 6                         Support and accountability
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  I don’t feel down about myself anymore and I f...
# 12                                                NaN
# 13  Weight loss\nHealth, my A1C levels went down\n...
# 14                                            Nothing
# 15   Support from staff\nPeer support towards my goal
# 16  Cholesterol level reduced \nImproved sleep\nHe...
# 17                           Healthier eating habits
# 18                                               None
# 19  Support from Sarah. It was invaluable to my su...
# 20          proper protein nutrition, mindful eating
# 21                                                NaN
# 22                                                NaN
#
#                                                   Q12  \
# 0   Was information and instruction given during t...
# 1                                                 Yes
# 2                                                 Yes
# 3                                                  No
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                Yes
# 12                                                NaN
# 13                                                Yes
# 14                                                 No
# 15                                                Yes
# 16                                                Yes
# 17                         Unsure / Prefer not to say
# 18                         Unsure / Prefer not to say
# 19                                                Yes
# 20                                                Yes
# 21                                                Yes
# 22                                                NaN
#
#                                                   Q13  \
# 0   Was your overall experience in the program pos...
# 1                                            Positive
# 2                          Unsure / Prefer not to say
# 3                          Unsure / Prefer not to say
# 4                                            Positive
# 5                                            Positive
# 6                                            Positive
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                           Positive
# 12                                                NaN
# 13                                           Positive
# 14                                           Negative
# 15                                           Positive
# 16                                           Positive
# 17                         Unsure / Prefer not to say
# 18                         Unsure / Prefer not to say
# 19                                           Positive
# 20                                           Positive
# 21                                           Positive
# 22                                                NaN
#
#                                                   Q14  \
# 0   What is the primary reason for your response t...
# 1                                 Helped me to focus
# 2                                                 NaN
# 3                    Your questions aren't numbered.
# 4                     Clear explanation by the nurse.
# 5                                   because it helped
# 6   lost weight and improved my health, I feel bet...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  Material was explained thoroughly and my clini...
# 14  Group setting for weight is not helpful. There...
# 15  Overall interaction with the provider was posi...
# 16                                    Health support
# 17                                                NaN
# 18                                                NaN
# 19                         The entire staffs support.
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                   Q15  \
# 0   Would you recommend this program to someone in...
# 1                                     Yes, Definitely
# 2                                       Yes, Probably
# 3                                                  No
# 4                                     Yes, Definitely
# 5                                     Yes, Definitely
# 6                                     Yes, Definitely
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                    Yes, Definitely
# 12                                                NaN
# 13                                    Yes, Definitely
# 14                                                 No
# 15                                    Yes, Definitely
# 16                                    Yes, Definitely
# 17                                      Yes, Probably
# 18                                                 No
# 19                                    Yes, Definitely
# 20                                    Yes, Definitely
# 21                                    Yes, Definitely
# 22                                                NaN
#
#                                                   Q16  \
# 0   What is the primary reason for your response t...
# 1                                Positive experience
# 2                                                 NaN
# 3                   Program seems very unstructured.
# 4   It helped me understand the root cause of my w...
# 5                               already did recommend
# 6              It just works if you put work into it
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  Changed how I thought about food being bad or ...
# 14  Needs better execution, material is fairly eas...
# 15              We all need to make lifestyle changes
# 16              Met my health goal using the program
# 17                                  It’s worth a try
# 18                                             Basic
# 19  You will be successful in your weight loss jou...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
#
#                                                   Q17
# 0   Do you have any suggestions or comments that y...
# 1                                                 NaN
# 2                                                 NaN
# 3               More structure. Better meal planning.
# 4                                                 NaN
# 5                                                 NaN
# 6   I wish it was offered at different times other...
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                   Longer than 30 minutes sessions.
# 17                                                NaN
# 18                                                NaN
# 19                                No, just thank you.
# 20                                                NaN
# 21  Easier scheduling in order to complete 12 cons...
# 22                                                NaN
#
# [23 rows x 25 columns]

# %%
# remove the first row of data
data3 = data.drop(data.index[0])
# remove NaN in q3 ang q4 column
data4 = data3.dropna(subset=['Q3', 'Q4'])

# remove row with lbs in its value in the columns Q3 and Q4
data5 = data4.drop(data4[data4['Q3'].str.contains('lbs')].index)

# convert the value in Q3 and Q4 to float
data5['Q3'] = data5['Q3'].astype(float)
data5['Q4'] = data5['Q4'].astype(float)

# add column weight loss of Q3 - Q4
data5['Weight Loss'] = data5['Q3'] - data5['Q4']
data5.head()
# Out:
#               StartDate              EndDate Progress Duration (in seconds)  \
# 1   2022-02-18 21:22:22  2022-02-18 21:26:04      100                   221
# 3   2022-02-28 12:13:25  2022-02-28 12:16:34      100                   188
# 5   2022-03-01 12:23:05  2022-03-01 12:25:04      100                   118
# 6   2022-03-03 10:53:47  2022-03-03 13:26:04      100                  9136
# 11  2022-03-09 09:11:15  2022-03-09 09:13:51      100                   155
#
#    Finished                RecordedDate DistributionChannel UserLanguage  \
# 1      True  2022-02-18 21:26:04.587000           anonymous           EN
# 3      True  2022-02-28 12:16:34.490000           anonymous           EN
# 5      True  2022-03-01 12:25:04.940000           anonymous           EN
# 6      True  2022-03-03 13:26:04.952000           anonymous           EN
# 11     True  2022-03-09 09:13:51.810000           anonymous           EN
#
#        Q1      Q2  ...  Q9                                                Q10  \
# 1   66-86    Male  ...  No                                                NaN
# 3   36-65  Female  ...  No  Emory University Barriatric program - liquid d...
# 5   66-86    Male  ...  No                                                NaN
# 6   36-65  Female  ...  No                                    Weight Watchers
# 11  36-65  Female  ...  No                                                NaN
#
#                                                   Q11  Q12  \
# 1                                                 NaN  Yes
# 3                                                 NaN   No
# 5   I cam e to realize things about myself that I ...  Yes
# 6                         Support and accountability   Yes
# 11  I don’t feel down about myself anymore and I f...  Yes
#
#                            Q13  \
# 1                     Positive
# 3   Unsure / Prefer not to say
# 5                     Positive
# 6                     Positive
# 11                    Positive
#
#                                                   Q14              Q15  \
# 1                                 Helped me to focus   Yes, Definitely
# 3                    Your questions aren't numbered.                No
# 5                                   because it helped  Yes, Definitely
# 6   lost weight and improved my health, I feel bet...  Yes, Definitely
# 11                                                NaN  Yes, Definitely
#
#                                        Q16  \
# 1                     Positive experience
# 3        Program seems very unstructured.
# 5                    already did recommend
# 6   It just works if you put work into it
# 11                                     NaN
#
#                                                   Q17 Weight Loss
# 1                                                 NaN        15.0
# 3               More structure. Better meal planning.         7.0
# 5                                                 NaN         9.0
# 6   I wish it was offered at different times other...         4.0
# 11                                                NaN        60.0
#
# [5 rows x 26 columns]

# %%
# group the data by the column Q2
grouped_data = data5.groupby('Q2')
# get group names
grouped_data.groups.keys()
# Out:
# dict_keys(['Female', 'Male'])

# %%
# add a new column of Q3 - Q4 into data 4

data4.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-fcc1b0cdb968> in <module>
#       1 # add a new column of Q3 - Q4 into data 4
# ----> 2 data4['weight loss'] = data4['Q3'] - data4['Q4']
#       3 data4.head()
#
# TypeError: unsupported operand type(s) for -: 'SeriesGroupBy' and 'SeriesGroupBy'

# %%
# get column names of data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   StartDate              23 non-null     object
#  1   EndDate                23 non-null     object
#  2   Progress               23 non-null     object
#  3   Duration (in seconds)  23 non-null     object
#  4   Finished               23 non-null     object
#  5   RecordedDate           23 non-null     object
#  6   DistributionChannel    23 non-null     object
#  7   UserLanguage           23 non-null     object
#  8   Q1                     17 non-null     object
#  9   Q2                     17 non-null     object
#  10  Q3                     17 non-null     object
#  11  Q4                     16 non-null     object
#  12  Q5                     15 non-null     object
#  13  Q6                     17 non-null     object
#  14  Q7                     8 non-null      object
#  15  Q8                     12 non-null     object
#  16  Q9                     17 non-null     object
#  17  Q10                    14 non-null     object
#  18  Q11                    13 non-null     object
#  19  Q12                    17 non-null     object
#  20  Q13                    17 non-null     object
#  21  Q14                    11 non-null     object
#  22  Q15                    17 non-null     object
#  23  Q16                    13 non-null     object
#  24  Q17                    6 non-null      object
# dtypes: object(25)
# memory usage: 4.6+ KB
