# %%
import pandas as pd; 
import numpy as np; 
import matplotlib.pyplot as plt

# %%
#read the data from the xlsx file
df = pd.read_excel('Copy_of_UNC_Weight_Management_Feedback_March.25.2022_00.50.xlsx')

# %%
df.head()
# Out:
#              StartDate              EndDate  Progress  Duration (in seconds)  \
# 0           Start Date             End Date  Progress  Duration (in seconds)
# 1  2022-02-18 21:22:22  2022-02-18 21:26:04       100                    221
# 2  2022-02-19 10:18:03  2022-02-19 10:20:08       100                    125
# 3  2022-02-28 12:13:25  2022-02-28 12:16:34       100                    188
# 4  2022-03-01 11:03:37  2022-03-01 11:09:16       100                    338
#
#    Finished                RecordedDate   DistributionChannel   UserLanguage  \
# 0  Finished               Recorded Date  Distribution Channel  User Language
# 1      True  2022-02-18 21:26:04.587000             anonymous             EN
# 2      True  2022-02-19 10:20:08.833000             anonymous             EN
# 3      True  2022-02-28 12:16:34.490000             anonymous             EN
# 4      True  2022-03-01 11:09:16.791000             anonymous             EN
#
# ...

# %%
# remove the second row
df1 = df.drop(df.index[0])

df1.head()
# Out:
#              StartDate              EndDate Progress Duration (in seconds)  \
# 1  2022-02-18 21:22:22  2022-02-18 21:26:04      100                   221
# 2  2022-02-19 10:18:03  2022-02-19 10:20:08      100                   125
# 3  2022-02-28 12:13:25  2022-02-28 12:16:34      100                   188
# 4  2022-03-01 11:03:37  2022-03-01 11:09:16      100                   338
# 5  2022-03-01 12:23:05  2022-03-01 12:25:04      100                   118
#
#   Finished                RecordedDate DistributionChannel UserLanguage  \
# 1     True  2022-02-18 21:26:04.587000           anonymous           EN
# 2     True  2022-02-19 10:20:08.833000           anonymous           EN
# 3     True  2022-02-28 12:16:34.490000           anonymous           EN
# 4     True  2022-03-01 11:09:16.791000           anonymous           EN
# 5     True  2022-03-01 12:25:04.940000           anonymous           EN
#
#       Q1      Q2  ...      Q8                          Q9  \
# ...

# %%
# t -test for the mean of the Duration (in seconds)
duration_mean = df1['Duration (in seconds)'].mean()
# independent sample t-test of duration_mean
from scipy import stats
t_test_duration = df1['Duration (in seconds)'].mean()
t_test_duration_std = df1['Duration (in seconds)'].std()
t_test_duration_std_div_sqrt = t_test_duration_std/np.sqrt(len(df1['Duration (in seconds)']))
t_test_duration_t_stat = (duration_mean - df1['Duration (in seconds)'].mean())/t_test_duration_std_div_sqrt
t_test_duration_p_value = 1 - stats.t.cdf(t_test_duration_t_stat, len(df1['Duration (in seconds)']))

# print the results
print('t-test for the mean of the Duration (in seconds)')
print('t-statistic:', t_test_duration_t_stat)
print('p-value:', t_test_duration_p_value)
# Out:
# t-test for the mean of the Duration (in seconds)
# t-statistic: 0.0
# p-value: 0.5

# %%
# scipy t-test for the mean of the Duration (in seconds)
from scipy import stats
t_test_duration = stats.ttest_1samp(df1['Duration (in seconds)'], df1['Duration (in seconds)'].mean())

# print the results
print('t-test for the mean of the Duration (in seconds)')
print('t-statistic:', t_test_duration[0])
print('p-value:', t_test_duration[1])
# Out:
# t-test for the mean of the Duration (in seconds)
# t-statistic: 0.0
# p-value: 1.0

# %%
#remove blank rows in df1['Duration (in seconds)']
clean_df = df1['Duration (in seconds)'].dropna(inplace=True)

# %%
from scipy.stats import ttest_ind


t_test_duration = ttest_ind(df1['Duration (in seconds)'], df1['Duration (in seconds)'].mean())
t_test_duration
# Out:
# /home/retech/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3702: RuntimeWarning: Degrees of freedom <= 0 for slice
#   return _methods._var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/retech/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:253: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Ttest_indResult(statistic=nan, pvalue=nan)
