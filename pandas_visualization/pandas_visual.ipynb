# %%
import numpy as np

# %%
import seaborn as sns
import pandas as pd

# %%
# %matplotlib inline

# %%
frame1 = pd.read_csv('df1', index_col=0)

# %%
frame1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
frame2 = pd.read_csv('df2')

# %%
frame2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
frame1['A'].hist(bins=10)
# Out:
# <AxesSubplot:>

# %%
frame1.count()
# Out:
# A    1000
# B    1000
# C    1000
# D    1000
# dtype: int64

# %%
#another method
frame1['A'].plot(kind='hist', grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
frame1['A'].plot.hist(grid=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
frame2.plot.area(alpha=0.5, grid=True)
# Out:
# <AxesSubplot:>

# %%
#comparative
frame2.plot.bar()
# Out:
# <AxesSubplot:>

# %%
#making it stacked
frame2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
frame2['a'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
frame1.plot.hist(x=frame1.index, y='B', figsize=(12,3))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-4e9e49548235> in <module>
# ----> 1 frame1.plot.hist(x=frame1.index, y='B', figsize=(12,3))
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in hist(self, by, bins, **kwargs)
#    1294             >>> ax = df.plot.hist(bins=12, alpha=0.5)
#    1295         """
# -> 1296         return self(kind="hist", by=by, bins=bins, **kwargs)
#    1297
#    1298     def kde(self, bw_method=None, ind=None, **kwargs):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918                 if is_integer(x) and not data.columns.holds_integer():
#     919                     x = data_cols[x]
# --> 920                 elif not isinstance(data[x], ABCSeries):
#     921                     raise ValueError("x must be a label or position")
# ...

# %%
frame1.plot.scatter(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
frame2.plot.box()
# Out:
# <AxesSubplot:>

# %%
#gen 2 column df

frame3 = pd.DataFrame(np.random.randn(100,2), columns=['A','B'])

# %%
frame3.head()
# Out:
#           A         B
# 0  0.442369 -0.968522
# 1  1.604283  0.583893
# 2 -0.365021  0.580023
# 3 -0.635617 -1.593662
# 4  2.834917  1.037516

# %%
frame3.plot.hexbin(x='A', y='B', gridsize=25)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
frame2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#kde can also be done with
frame2['a'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
frame2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
frame1.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
